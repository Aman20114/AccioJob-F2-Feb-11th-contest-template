# %% [markdown]
# <a href="https://colab.research.google.com/github/Aman20114/AccioJob-F2-Feb-11th-contest-template/blob/main/pybasics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello ")
# Out:
# hello

# %% [markdown]
# [link text](https://)!pip install pandas

# %% [markdown]
# What is Python Language

# %% [markdown]
# #Python is a type of pogramming language which we can use for communicating with computers or technology

# %% [markdown]
# Syntax refers to the set of rules that definesthe combination of symbols that are considered to be correctly structured programs in a language

# %% [markdown]
# semantics of python language

# %% [markdown]
# symantics of pyhton lang refers to the meaning of interpretation of symbols,character and comands in a lang. It is about what the code is supposed to do when it runs.

# %%
name = "Aman"
Name = "Aman"
name == Name
# Out:
# True

# %% [markdown]
# Syntax or python language

# %%
name = "Aman"
Name = "aman"
name == Name
# Out:
# False

# %%
age = int (input("Enter your age: "))
if age > 18 :
  print ("You are elligible for driving ")
else:
  print ("You are not elligible for driving ")
# Out:
# Enter your age: 18
# You are not elligible for driving

# %%
1+2+3+5
# Out:
# 11

# %%
## we use backslash for continuing the code on the next line
1+2+6+6+\
4+1
# Out:
# 20

# %% [markdown]
# Vaiable naming convention

# %%
'''
Aman 25
'''
# Out:
# '\nAman 25\n'

# %%
name = input("Enter my name: ")
# Out:
# Enter my name: Aman

# %%
print(name)
# Out:
# Aman
